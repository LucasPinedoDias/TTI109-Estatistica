# %%
import pandas as pd
import matplotlib.pyplot as plt
dados = [['Estados Unidos', 15], ['Tanzânia', 1],
         ['Grã-Bretanha', 1], ['Itália', 4],
         ['Quênia', 9], ['Brasil', 2], ['Etiópia', 2],
         ['México', 4], ['Nova Zelândia', 1],
         ['África do Sul', 2], ['Marrocos', 1]]
tabela = pd.DataFrame(data=dados,columns=['Países', 'Frequência'])
display(tabela)
pizza = plt.pie(tabela['Frequência'], labels=tabela['Países'], autopct='%1.1f%%')
# Out:
#             Países  Frequência
# 0   Estados Unidos          15
# 1         Tanzânia           1
# 2     Grã-Bretanha           1
# 3           Itália           4
# 4           Quênia           9
# 5           Brasil           2
# 6          Etiópia           2
# 7           México           4
# 8    Nova Zelândia           1
# 9    África do Sul           2
# 10        Marrocos           1

# %%
dados_simplificados = [['Américas', 21], ['Europa', 5],
                       ['África', 15], ['Oceania', 1]]
tabela = pd.DataFrame(data=dados_simplificados,columns=['Continentes', 'Frequência'])
pizza = plt.pie(tabela['Frequência'], labels=tabela['Continentes'], autopct='%1.1f%%')

# %%
dados3 = [['Alemanha', 44],['Grã-Bretanha',69],
          ['EUA', 104], ['Rússia', 82], ['China',88]]
tabela3 = pd.DataFrame(data=dados3, columns=['País', 'Medalhas'])
print(tabela3)
tabela3 = tabela3.sort_values(by='Medalhas', ascending=False)
print(tabela3)
pareto = plt.bar(tabela3['País'], tabela3 ['Medalhas'],color='red')
plt.ylabel('Número de Medalhas')
plt.title('Olímpiadas de Londres - 2012')
# Out:
#            País  Medalhas
# 0      Alemanha        44
# 1  Grã-Bretanha        69
# 2           EUA       104
# 3        Rússia        82
# 4         China        88
#            País  Medalhas
# 2           EUA       104
# 4         China        88
# 3        Rússia        82
# 1  Grã-Bretanha        69
# 0      Alemanha        44
# Text(0.5, 1.0, 'Olímpiadas de Londres - 2012')

# %%
dados4 = [[17.1, 28.7], [17.5, 47.5], [18.9, 31.8],
          [17.1, 28.1], [20.0, 40.3], [18.6, 33.8],
          [14.4, 49.8], [16.5, 37.5], [13.3, 42.5],
          [18.4, 31.9]]
tabela_sal = pd.DataFrame(data=dados4,columns=['Alunos', 'Salario'])
display(tabela_sal)
# Out:
#    Alunos  Salario
# 0    17.1     28.7
# 1    17.5     47.5
# 2    18.9     31.8
# 3    17.1     28.1
# 4    20.0     40.3
# 5    18.6     33.8
# 6    14.4     49.8
# 7    16.5     37.5
# 8    13.3     42.5
# 9    18.4     31.9
